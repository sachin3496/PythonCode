# %%
class Human : 
    """This is Human Class."""
    name = 'insaan' #class variable
    def get_name(self):
        print(name)
    def set_name(self,data):
        name = data

p1 = Human()

# %%
p1.get_name()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fcab85ae1370> in <module>()
# ----> 1 p1.get_name()
#
# <ipython-input-1-359d1dcca4d1> in get_name(self)
#       3     name = 'insaan' #class variable
#       4     def get_name(self):
# ----> 5         print(name)
#       6     def set_name(self,data):
#       7         name = data
#
# NameError: name 'name' is not defined

# %%
p1.set_name('sachin')

# %%
p1.__dict__
# Out:
# {}

# %%
Human.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__doc__': 'This is Human Class.',
#               'name': 'insaan',
#               'get_name': <function __main__.Human.get_name(self)>,
#               'set_name': <function __main__.Human.set_name(self, data)>,
#               '__dict__': <attribute '__dict__' of 'Human' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Human' objects>})

# %%
class Human : 
    """This is Human Class."""
    name = 'insaan' #class variable
    def get_name(self):
        print("Object Name --> ",self.name)
        print("Class Name --> ",Human.name)
    def set_name(self,data):
        self.name = data

p1 = Human()
p1.get_name()
p1.__dict__
# Out:
# Object Name -->  insaan
# Class Name -->  insaan
# {}

# %%
p1.set_name('sachin')
p1.get_name()
p1.__dict__
# Out:
# Object Name -->  sachin
# Class Name -->  insaan
# {'name': 'sachin'}

# %%
p2  = Human()
p2.get_name()
# Out:
# Object Name -->  insaan
# Class Name -->  insaan

# %%
l = [ 1,2,3,4]
while True : 
    print(l.pop())
# Out:
# 4
# 3
# 2
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-1f1481a7bd7d> in <module>()
#       1 l = [ 1,2,3,4]
#       2 while True :
# ----> 3     print(l.pop())
#
# IndexError: pop from empty list

# %%
class A : 
    def show(k):
        print(k.name)
        print("Hello world")

# %%
x = A()

# %%
x.name = 'sachin'
x.show()
# Out:
# sachin
# Hello world

# %%
class A : 
    def show(self):
        pass
    def disp(k):
        pass
    def hi(bye):
        pass

# %%
class A : 
    def show(self):
        print("Hello World")

# %%
a = A()
a.show()
# Out:
# Hello World

# %%
A.show({})
# Out:
# Hello World
