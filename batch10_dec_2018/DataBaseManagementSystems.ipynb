# %%
import socket

# %%
dir(socket)
# Out:
# ['AF_APPLETALK',
#  'AF_DECnet',
#  'AF_INET',
#  'AF_INET6',
#  'AF_IPX',
#  'AF_IRDA',
#  'AF_SNA',
#  'AF_UNSPEC',
#  'AI_ADDRCONFIG',
#  'AI_ALL',
#  'AI_CANONNAME',
#  'AI_NUMERICHOST',
#  'AI_NUMERICSERV',
#  'AI_PASSIVE',
#  'AI_V4MAPPED',
#  'AddressFamily',
#  'AddressInfo',
#  'CAPI',
#  'EAGAIN',
#  'EAI_AGAIN',
#  'EAI_BADFLAGS',
#  'EAI_FAIL',
#  'EAI_FAMILY',
#  'EAI_MEMORY',
#  'EAI_NODATA',
#  'EAI_NONAME',
#  'EAI_SERVICE',
#  'EAI_SOCKTYPE',
#  'EBADF',
#  'EWOULDBLOCK',
#  'INADDR_ALLHOSTS_GROUP',
#  'INADDR_ANY',
#  'INADDR_BROADCAST',
#  'INADDR_LOOPBACK',
#  'INADDR_MAX_LOCAL_GROUP',
#  'INADDR_NONE',
#  'INADDR_UNSPEC_GROUP',
#  'IPPORT_RESERVED',
#  'IPPORT_USERRESERVED',
#  'IPPROTO_ICMP',
#  'IPPROTO_IP',
#  'IPPROTO_RAW',
#  'IPPROTO_TCP',
#  'IPPROTO_UDP',
#  'IPV6_CHECKSUM',
#  'IPV6_DONTFRAG',
#  'IPV6_HOPLIMIT',
#  'IPV6_HOPOPTS',
#  'IPV6_JOIN_GROUP',
#  'IPV6_LEAVE_GROUP',
#  'IPV6_MULTICAST_HOPS',
#  'IPV6_MULTICAST_IF',
#  'IPV6_MULTICAST_LOOP',
# ...
